# %%
from empyrial import empyrial, Engine

portfolio = Engine(
    start_date = "2014-01-01",
    portfolio = ["GOOG", "AAPL", "HPQ", "AMD","BA"],
    optimizer = "MINVAR",
    rebalance = "1y",
    risk_manager = {"Stop Loss" : -0.25}
)

portfolio.weights
# Out:
# [0.21949, 0.21299, 0.20617, 0.16449, 0.19686]

# %%
empyrial(portfolio)
# Out:
# Start date: 2014-01-01
# End date: 2021-09-27
#                      Backtest
#
# Annual return          29.41%
# Cumulative return      617.3%
# Annual volatility     25.39 %
# Winning day ratio      56.23%
# Sharpe ratio             1.14
# Calmar ratio             0.69
# Information ratio         0.0
# Stability                0.95
# Max Drawdown         -42.24 %
# Sortino ratio            1.61
# Skew                     -0.6
# Kurtosis                11.51
# Tail Ratio               0.97
# Common sense ratio        1.2
# Daily value at risk    -3.0 %
# Alpha                     0.1
# Beta                     1.27
# (None, None, None, None, None, None, None, None, None)

# %%
empyrial.orderbook[empyrial.orderbook.columns[-1]]
# Out:
# GOOG    0.21949
# AAPL    0.21299
# HPQ     0.20617
# AMD     0.16449
# BA      0.19686
# Name: 2021-09-27, dtype: float64
