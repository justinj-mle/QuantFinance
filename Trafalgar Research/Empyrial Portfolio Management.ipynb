# %%
from empyrial import empyrial, Engine

portfolio = Engine(
    start_date = "2014-01-01",
    portfolio = ["ADBE", "ADSK", "GPN","MA"],
    optimizer = "MEANVAR",
    rebalance = "1y",
    risk_manager = {"Stop Loss" : -0.25},
    max_vol = 0.35
)

portfolio.weights
# Out:
# [0.24496, 0.26845, 0.24796, 0.23863]

# %%
empyrial(portfolio)
# Out:
# Start date: 2014-01-01
# End date: 2021-09-29
#                      Backtest
#
# Annual return          27.49%
# Cumulative return     549.31%
# Annual volatility      26.0 %
# Winning day ratio      55.64%
# Sharpe ratio             1.06
# Calmar ratio              0.8
# Information ratio         0.0
# Stability                0.99
# Max Drawdown         -34.24 %
# Sortino ratio            1.52
# Skew                    -0.18
# Kurtosis                 9.43
# Tail Ratio               0.93
# Common sense ratio       1.14
# Daily value at risk    -3.0 %
# Alpha                     0.1
# Beta                     1.29
# (None, None, None, None, None, None, None, None, None)

# %%
empyrial.orderbook[empyrial.orderbook.columns[-1]]
# Out:
# ADBE    0.24496
# ADSK    0.26845
# GPN     0.24796
# MA      0.23863
# Name: 2021-09-29, dtype: float64
